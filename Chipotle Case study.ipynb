# %%
import pandas as pd
import numpy as np
df = pd.read_csv("D:/Sem 2/python/Assignments/3/chipotle.csv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
# the first 10 entries
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# the number of observations in the dataset & columns
df.shape
# Out:
# (4591, 5)

# %%
# Print the name of all the columns
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Which was the most ordered item
df.describe()
# Out:
#           order_id     quantity
# count  4591.000000  4591.000000
# mean    921.166848     1.076236
# std     525.440106     0.411522
# min       1.000000     1.000000
# 25%     473.500000     1.000000
# 50%     922.000000     1.000000
# 75%    1383.000000     1.000000
# max    1825.000000    15.000000

# %%
# Most ordered item...//
df.max(axis=0)
# Out:
# order_id                  1825
# quantity                    15
# item_name    Veggie Soft Tacos
# dtype: object

# %%
# How many items were ordered -Unique items..//
degree_counts = df['item_name'].value_counts()
degree_counts
# Out:
# Chicken Bowl                             721
# Chicken Burrito                          553
# Chips and Guacamole                      475
# Steak Burrito                            364
# Canned Soft Drink                        297
# Steak Bowl                               211
# Chips                                    210
# Bottled Water                            160
# Chicken Soft Tacos                       114
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       107
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            93
# Barbacoa Burrito                          88
# Veggie Bowl                               85
# Carnitas Bowl                             66
# Barbacoa Bowl                             65
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
# How many items were ordered in Total...//
df['item_name'].count()
# Out:
# 4591

# %%
# How many orders were made in the period../
df['order_id'].count()
# Out:
# 4591

# %%
# How many different items are sold
df['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
# total number of unique items in the order..//
len(df['item_name'].unique())
# Out:
# 51

# %%
df[['item_price']].dtypes
# Out:
# item_price    object
# dtype: object

# %%
# How much was the revenue for the period in the dataset..///
# Removing the dollar sign from the item_price list to add
df['item_price'] = df['item_price'].str.replace('$', '')
df['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#          ...
# 4561    17.50
# 4562     9.25
# 4563     4.45
# 4564    11.25
# 4565     1.25
# 4566     8.75
# 4567     4.45
# 4568     1.50
# 4569     8.75
# 4570     1.50
# 4571     1.25
# 4572     9.39
# 4573     8.75
# 4574     8.75
# 4575     4.45
# 4576    11.25
# 4577     1.25
# 4578     9.25
# 4579     4.45
# 4580    11.25
# 4581     8.75
# 4582     3.00
# 4583     8.75
# 4584     2.15
# 4585     1.25
# 4586    11.25
# 4587    11.25
# 4588     4.45
# 4589    11.25
# 4590       NaN
# ...

# %%
# Removing the NAN value from the column..//
df.dropna(axis = 0,subset = ['item_price'], inplace=True)

# %%
# Total Revenue earned for the period is the summation of item_price column
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
# how to convert object/string to float
df['item_price'] = df['item_price'].astype(float)

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
# Total revenue in that period.
Total = df['item_price'].sum()
print (Total)
# Out:
# 34255.96

# %%
# Average amount per order
df['item_price'].mean()
# Out:
# 7.463172113289863
